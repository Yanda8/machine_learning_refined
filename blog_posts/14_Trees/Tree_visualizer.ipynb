# %%
# import standard plotting and animation
import matplotlib.pyplot as plt
from matplotlib import gridspec
from matplotlib.ticker import FormatStrFormatter
import matplotlib.animation as animation
from mpl_toolkits.mplot3d import Axes3D
from IPython.display import clear_output

# import autograd functionality
import autograd.numpy as np
import math
import time
from matplotlib import gridspec
import copy
from matplotlib.ticker import FormatStrFormatter
from inspect import signature

# this is needed to compensate for %matplotlib notebook's tendancy to blow up images when plotted inline
from matplotlib import rcParams
rcParams['figure.autolayout'] = True
# %matplotlib notebook

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # ok

# %%
def make_stumps(x,y):
    # for which dimension the stump is defined along
    splits = []
    dims = []

    # important constants: dimension of input N and total number of points P
    N = np.shape(self.x)[0]              
    P = np.size(self.y)

    # begin outer loop - loop over each dimension of the input - create split points and dimensions
    for n in range(N):
        # make a copy of the n^th dimension of the input data (we will sort after this)
        x_n = copy.deepcopy(self.x[n,:])

        # sort x_n and y_n according to ascending order in x_n
        sorted_inds = np.argsort(x_n,axis = 0)
        x_n = x_n[sorted_inds]

        # loop over points and create stump in between each 
        # in dimension n
        for p in range(P - 1):
            if self.y[p] != self.y[p+1]:
                # compute split point
                split = (x_n[p] + x_n[p+1])/float(2)

                ### create non-zero stump to 'left' of split ###
                # compute and store split point
                splits.append(split)
                dims.append(n)

# %%
### create prototype steps ###
def create_proto_stumps(x,y):
    ### create stumps out of splits and dims ###
    all_steps = []
    for ind in range(len(dims)):
        # create step function
        split = splits[ind]
        dim = dims[ind]
        step = lambda x,w,split=split,dim=dim: np.array([(w[0] if v <= split else w[1]) for v in x[dim,:]])

        # add to list
        all_steps.append(copy.deepcopy(step))
    return all_steps

# %% [markdown]
# # create random tree

# %%
### create prototype steps ###
def create_proto_stumps():
    # for which dimension the stump is defined along
    splits = []
    dims = []

    # important constants: dimension of input N and total number of points P
    N = np.shape(x)[0]              
    P = np.size(y)

    # begin outer loop - loop over each dimension of the input - create split points and dimensions
    for n in range(N):
        # make a copy of the n^th dimension of the input data (we will sort after this)
        x_n = copy.deepcopy(x[n,:])

        # sort x_n and y_n according to ascending order in x_n
        sorted_inds = np.argsort(x_n,axis = 0)
        x_n = x_n[sorted_inds]

        # loop over points and create stump in between each 
        # in dimension n
        for p in range(P - 1):
            if self.y[p] != self.y[p+1]:
                # compute split point
                split = (x_n[p] + x_n[p+1])/float(2)

                ### create non-zero stump to 'left' of split ###
                # compute and store split point
                splits.append(split)
                dims.append(n)

    ### create stumps out of splits and dims ###
    all_steps = []
    for ind in range(len(dims)):
        # create step function
        split = splits[ind]
        dim = dims[ind]
        step = lambda x,w,split=split,dim=dim: np.array([(w[0] if v <= split else w[1]) for v in x[dim,:]])

        # add to list
        all_steps.append(copy.deepcopy(step))
    return all_steps

# %% [markdown]
# OK - how do you want to program this.  It really is pretty fucking useless, and organizing the split points / levels is the thing that throws one for a loop.  What kind of architecture do we want to use here - a list of lists?  I suppose so yes.
#
# - blah
#
#
# - blah

# %% [markdown]
# - ok so now what

# %% [markdown]
# - obviously you need a tree like structure, what should we build to contain it?
#
# - also - ah yes you need no optimizer here
#
# - ok so then how do you do that

# %%
Damn, do we even want to do this?  Whats the point? 


Yes - a dictionary

# %%
def make_tree(dims,splits,levels):
    # make first split, then recurse
    for dim in range(dims):

# %%
### create prototype steps ###
def create_random_tree(num_splits):
    splits = []
    levels = []
    dims = []
    
    # loop over and do 
    for k in range(num_splits):
        # select dimnsion at random
        dim = np.round(np.random.rand(1))
        dims.append(dim)

        # select random split along dimension
        split = np.random.rand(1)
        splits.append(split)
        
        # create levels on either side of split

# %%
## This code cell will not be shown in the HTML version of this notebook
# build 4 instances of a composition basis: line and tanh
x = np.linspace(-5,5,100)
fig = plt.figure(figsize = (10,3))

for m in range(1,5):
    # make basis element
    w_0 = 0.1*np.random.randn(1)
    w_1 = 0.1*np.random.randn(1)
    w_2 = np.random.randn(1)
    fm = w_2*np.sign(w_0 + w_1*x)
    
    # make basis element
    w_0 = 0.1*np.random.randn(1)
    w_1 = 0.1*np.random.randn(1)
    w_2 = np.random.randn(1)
    gm = w_2*np.sign(w_0 + w_1*x)
    
    # make basis element
    w_0 = 0.1*np.random.randn(1)
    w_1 = 0.1*np.random.randn(1)
    w_2 = np.random.randn(1)
    bm = w_2*np.sign(w_0 + w_1*x)
    fm += gm
    fm += bm
    fm_table = np.stack((x,fm),axis = 1)
    
    # plot the current element
    ax = fig.add_subplot(1,4,m)
    ax.scatter(fm_table[:,0],fm_table[:,1],c='r',s = 20,zorder = 3)
    ax.set_title('$f$ instance ' + str(m),fontsize = 18)

    # clean up plot
    ax.grid(True, which='both')
    ax.axhline(y=0, color='k')
    ax.axvline(x=0, color='k')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">
