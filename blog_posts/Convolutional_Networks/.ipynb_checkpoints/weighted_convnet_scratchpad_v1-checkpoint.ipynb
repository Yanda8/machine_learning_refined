# %%
from scipy import signal as sig

# imports from custom library
import sys
sys.path.append('../../')
import matplotlib.pyplot as plt
plt.rc('text', usetex=True)
from mlrefined_libraries import convnets_library as convlib
from mlrefined_libraries import basics_library as baslib
from mlrefined_libraries import superlearn_library as superlearn
from mlrefined_libraries import multilayer_perceptron_library as network_lib

import autograd.numpy as np
from autograd import grad as compute_grad   
import numpy as npo

import pandas as pd
import cv2
import csv
import pickle
import glob
import time
import copy
from datetime import datetime 

#this is needed to compensate for matplotlib notebook's tendancy to blow up images when plotted inline
# %matplotlib notebook
from matplotlib import rcParams
rcParams['figure.autolayout'] = True

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Load in data

# %% [markdown]
# Load in data.

# %%
# load in dataset
datapath = '../../mlrefined_datasets/convnet_datasets/feat_face_data.csv'
data = np.loadtxt(datapath,delimiter = ',')

# %% [markdown]
# Contrast normalize images.

# %%
# extract input tensor
tensor = data[:,:-1]
y = data[:,-1:]

# contrast normalize image data
def contrast_normalize(data):
    data_means = np.mean(data,axis = 0)
    data = data - data_means
    data_stds = np.std(data,axis = 0)
    data = data/data_stds
    return data

# contrast normalize the input 
tensor_decontrast = contrast_normalize(tensor.T).T

# make new data based on fixed kernel convolutions
new_data = np.concatenate((tensor_decontrast,y),axis = 1)

# %%
test_data = copy.deepcopy(new_data[:10])

# %% [markdown]
# ## learned convolution features

# %%
# load in data - for this one split up training and testing
ind = np.random.permutation(len(test_data))

# split it up
data_train = test_data[ind[:2],:]
data_test = test_data[ind[2:],:]

# load data into network
demo = convlib.network_learner.Network()
demo.input_data(data_train,data_test,normalize = True)

# %%
# choose cost function
demo.choose_cost(cost_name = 'twoclass_softmax')

# setup network architecture
activation_name = 'relu'
num_kernels = 2
layer_sizes = [128,10,1]
demo.architecture_settings(activation_name,layer_sizes,num_kernels)

# %%
# setup optimizer
demo.optimizer_settings(alpha = 10**(-1),max_its = 2,version = 'normalized',scale = 0.1)

# %%
# fit
demo.fit(verbose = True)
# Out:
# starting optimization...
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-8-e67d6efbf507> in <module>()
#       1 # fit
# ----> 2 demo.fit(verbose = True)
#
# /Users/Nurgetson/Dropbox/github_repos/mlrefined/mlrefined_libraries/convnets_library/network_learner.py in fit(self, **kwargs)
#     132
#     133         # run optimizer
# --> 134         self.weight_history = self.opt.gradient_descent(self.training_cost,self.w_init,self.alpha,self.max_its,self.beta,self.version,verbose=verbose)
#     135
#     136     ####### show cost function plots #######
#
# /Users/Nurgetson/Dropbox/github_repos/mlrefined/mlrefined_libraries/convnets_library/optimizers.py in gradient_descent(self, g, w, alpha, max_its, beta, version, **kwargs)
#      39         for k in range(max_its):
#      40             # plug in value into func and derivative
# ---> 41             grad_eval = grad(w)
#      42             grad_eval.shape = np.shape(w)
#      43
#
# /Users/Nurgetson/anaconda/lib/python3.5/site-packages/autograd/wrap_util.py in nary_f(*args, **kwargs)
#      18             else:
#      19                 x = tuple(args[i] for i in argnum)
# ---> 20             return unary_operator(unary_f, x, *nary_op_args, **nary_op_kwargs)
#      21         return nary_f
#      22     return nary_operator
#
# /Users/Nurgetson/anaconda/lib/python3.5/site-packages/autograd/differential_operators.py in grad(fun, x)
#      22     arguments as `fun`, but returns the gradient instead. The function `fun`
#      23     should be scalar-valued. The gradient has the same type as the argument."""
# ---> 24     vjp, ans = _make_vjp(fun, x)
#      25     if not vspace(ans).size == 1:
#      26         raise TypeError("Grad only applies to real scalar-output functions. "
#
# /Users/Nurgetson/anaconda/lib/python3.5/site-packages/autograd/core.py in make_vjp(fun, x)
#       8 def make_vjp(fun, x):
#       9     start_node = VJPNode.new_root(x)
# ---> 10     end_value, end_node =  trace(start_node, fun, x)
#      11     if end_node is None:
#      12         def vjp(g): return vspace(x).zeros()
#
# /Users/Nurgetson/anaconda/lib/python3.5/site-packages/autograd/tracer.py in trace(start_node, fun, x)
#       8     with trace_stack.new_trace() as t:
#       9         start_box = new_box(x, t, start_node)
# ---> 10         end_box = fun(start_box)
#      11         if isbox(end_box) and end_box._trace == start_box._trace:
#      12             return end_box._value, end_box._node
#
# /Users/Nurgetson/anaconda/lib/python3.5/site-packages/autograd/wrap_util.py in unary_f(x)
#      13                 else:
#      14                     subargs = subvals(args, zip(argnum, x))
# ---> 15                 return fun(*subargs, **kwargs)
#      16             if isinstance(argnum, int):
#      17                 x = args[argnum]
#
# /Users/Nurgetson/Dropbox/github_repos/mlrefined/mlrefined_libraries/convnets_library/cost_functions.py in twoclass_softmax(self, w)
#      32     # two-class softmax / logistic regression cost
#      33     def twoclass_softmax(self,w):
# ---> 34         cost = np.sum(np.log(1 + np.exp((-self.y)*(self.predict(self.x,w)))))
#      35         return cost
#      36
#
# /Users/Nurgetson/Dropbox/github_repos/mlrefined/mlrefined_libraries/convnets_library/network_learner.py in predict_training(self, x, w)
#      90     def predict_training(self,x,w):
#      91         # feature trasnsformations
# ---> 92         f = self.architectures.training_architecture(x,w[0],w[1])
#      93
#      94         # compute linear model
#
# /Users/Nurgetson/Dropbox/github_repos/mlrefined/mlrefined_libraries/convnets_library/architectures.py in compute_general_network_features(self, x, inner_weights, kernels)
#     116     def compute_general_network_features(self,x,inner_weights,kernels):
#     117         # pass input through convolution layers
# --> 118         x_conv = self.conv_layer(x,kernels)
#     119         print (np.shape(x_conv))
#     120         print (type(x_conv))
#
# /Users/Nurgetson/Dropbox/github_repos/mlrefined/mlrefined_libraries/convnets_library/architectures.py in conv_layer(self, tensor, kernels)
#      61
#      62         # pad tensor
# ---> 63         kernel = kernels[0]
#      64         padded_tensor = self.pad_tensor(tensor,kernel)
#      65
#
# /Users/Nurgetson/anaconda/lib/python3.5/site-packages/autograd/tracer.py in f_wrapped(*args, **kwargs)
#      42             parents = tuple(box._node for _     , box in boxed_args)
#      43             argnums = tuple(argnum    for argnum, _   in boxed_args)
# ---> 44             ans = f_wrapped(*argvals, **kwargs)
#      45             node = node_constructor(ans, f_wrapped, argvals, kwargs, argnums, parents)
#      46             return new_box(ans, trace, node)
#
# /Users/Nurgetson/anaconda/lib/python3.5/site-packages/autograd/tracer.py in f_wrapped(*args, **kwargs)
#      46             return new_box(ans, trace, node)
#      47         else:
# ---> 48             return f_raw(*args, **kwargs)
#      49     f_wrapped.fun = f_raw
#      50     f_wrapped._is_autograd_primitive = True
#
# /Users/Nurgetson/anaconda/lib/python3.5/site-packages/autograd/numpy/numpy_boxes.py in __getitem__(A, idx)
#      11
#      12     @primitive
# ---> 13     def __getitem__(A, idx): return A[idx]
#      14
#      15     # Constants w.r.t float data just pass though
#
# IndexError: invalid index to scalar variable.

# %%
demo.predict_training(data_train[:,:-1],demo.w_init)
# Out:
# (2, 128)
# <class 'numpy.ndarray'>
# 20
# (2, 10)
# <class 'numpy.ndarray'>
# array([[ 0.189435  ],
#        [ 0.18522412]])

# %%
demo.training_cost(demo.w_init)
# Out:
# (2, 128)
# <class 'numpy.ndarray'>
# 20
# (2, 10)
# <class 'numpy.ndarray'>
# 1.2286245830280929

# %%
from autograd import grad as compute_grad

# %%
test_grad = compute_grad(demo.training_cost)

# %%
wa = test_grad(demo.w_init)
# Out:
# (2, 128)
# <class 'numpy.ndarray'>
# [[<autograd.numpy.numpy_boxes.ArrayBox object at 0x1387656c8>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x12467c088>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x138797248>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x12467ee08>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x13883c6c8>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x1246784c8>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x121a03748>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x124662908>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x121ae4f48>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x122d64588>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x121b87748>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x122d4bc88>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x121a168c8>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x122d74648>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x121a1b888>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x122d59bc8>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x121c8b288>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x122d56848>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x121cf3808>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x122d58e08>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x121d61348>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x123a68a08>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x121dca608>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x123a57dc8>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x121dd0c88>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x123a59d48>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x121e38548>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x123a46908>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x121ea7388>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x123a82f08>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x121f46d88>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x123dc33c8>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x121f775c8>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x123dfd248>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x121fe6f88>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x123df9c88>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x12201d9c8>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x123dc92c8>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x12208b208>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x123dca5c8>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x12215c388>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x124ae9788>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x1222026c8>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x124af1048>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x1222702c8>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x124aee788>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x1225d4e48>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x124aedec8>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x1226ab548>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x124adf788>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x122759108>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x122d2fb88>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x1227c7b48>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x122d27a88>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x122830208>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x122d1af88>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x1386fea88>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x122cf9288>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x1387359c8>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x122d1b988>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x1387d9d08>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x124cfc8c8>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x138842f88>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x124ce2fc8>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x1388b0448>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x124cd6f48>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x121e69508>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x124ccca88>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x121df0848>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x124cff6c8>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x121cb1dc8>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x124cfecc8>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x121c0b8c8>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x1396d0408>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x121bacd88>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x1396dba08>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x121b7b648>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x1396e80c8>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x121a5a908>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x1396f1c48>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x121acb548>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x1396fabc8>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x121c305c8>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x123815288>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x138892ac8>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x123816e88>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x13890c808>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x1238244c8>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x138986688>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x12382fbc8>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x13967da08>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x123825288>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x139688388>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x124276808>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x1396b5c88>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x12424f1c8>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x1396c2ac8>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x12425ab48>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x1230a5208>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x124259448>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x12309a908>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x124269ac8>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x12308e748>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x123f1a4c8>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x12309f248>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x123f27c88>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x1230b8688>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x123f37e08>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x1236d6548>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x123f29448>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x1236e2c08>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x123f066c8>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x1236c3188>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x123f32dc8>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x1236fb9c8>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x124178c08>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x1236cb0c8>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x12417c648>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x1236d8f08>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x124158d48>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x1237bbd48>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x12415bc88>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x123793e48>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x12415df08>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x1237af508>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x123cb4d48>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x1237a2748>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x123c89588>]
#  [<autograd.numpy.numpy_boxes.ArrayBox object at 0x138765048>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x12467c988>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x13879c188>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x12467efc8>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x138873108>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x124678c48>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x121ae4248>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x124657408>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x121a11408>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x122d64e08>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x121b87bc8>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x122d67948>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x121bb9888>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x122d74fc8>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x121c1d708>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x122d71b88>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x121cbd4c8>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x122d44d88>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x121d2ae08>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x123a664c8>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x121d92788>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x123a76a08>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x121dd0e48>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x123a78188>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x121e01ac8>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x123a479c8>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x121ea1b88>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x123a69448>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x121f0f708>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x123dcce08>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x121f77048>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x123dc6748>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x121f7de88>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x123dd1bc8>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x121fe6588>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x123dfa408>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x122054a48>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x123dfc208>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x1220bd4c8>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x124b010c8>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x1221cb0c8>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x124ad2c88>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x12226a408>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x124aee388>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x12259d108>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x124afc308>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x1226799c8>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x124ad3488>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x1226b0d88>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x124afe348>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x122791288>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x122d05dc8>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x1227f9948>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x122cfb608>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x122867ec8>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x122d17888>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x138703408>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x122cf9e88>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x1387a3308>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x122d18e48>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x13880b308>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x124ce0588>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x1388424c8>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x124cd2988>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x1220db808>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x124cf06c8>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x121d8dcc8>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x124cee5c8>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x121cee648>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x124cffc88>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x121c486c8>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x1396cb348>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x121c3b2c8>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x1396d69c8>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x121bac548>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x1396df648>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x121a8c648>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x1396e8d08>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x121ad7d48>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x1396fa548>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x121a45648>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x139700e88>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x121bf9bc8>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x123816388>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x1388eef48>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x123809908>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x138931bc8>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x1238216c8>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x139650988>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x123838b48>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x139688a48>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x12383d5c8>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x13969c2c8>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x124244788>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x1396bb688>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x124258d08>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x1396c8588>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x1242780c8>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x1230a5d08>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x124259b48>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x1230be3c8>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x124273108>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x12308eec8>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x123f18788>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x123083808>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x123f2d348>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x123099148>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x123f14a48>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x1237007c8>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x123f06048>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x1236d0b08>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x123f32648>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x1236c3a88>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x124150f48>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x1236e7e88>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x12414dc48>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x1236d4cc8>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x12417e188>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x123794588>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x12415f808>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x12378ea08>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x1241472c8>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x1237a3e08>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x12414f848>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x1237be088>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x123cb8808>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x1237a6708>
#   <autograd.numpy.numpy_boxes.ArrayBox object at 0x123c89e08>]]
# 20
# (2, 10)
# <class 'autograd.numpy.numpy_boxes.ArrayBox'>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-affdf952e630> in <module>()
# ----> 1 wa = test_grad(demo.w_init)
#
# /Users/Nurgetson/anaconda/lib/python3.5/site-packages/autograd/wrap_util.py in nary_f(*args, **kwargs)
#      18             else:
#      19                 x = tuple(args[i] for i in argnum)
# ---> 20             return unary_operator(unary_f, x, *nary_op_args, **nary_op_kwargs)
#      21         return nary_f
#      22     return nary_operator
#
# /Users/Nurgetson/anaconda/lib/python3.5/site-packages/autograd/differential_operators.py in grad(fun, x)
#      22     arguments as `fun`, but returns the gradient instead. The function `fun`
#      23     should be scalar-valued. The gradient has the same type as the argument."""
# ---> 24     vjp, ans = _make_vjp(fun, x)
#      25     if not vspace(ans).size == 1:
#      26         raise TypeError("Grad only applies to real scalar-output functions. "
#
# /Users/Nurgetson/anaconda/lib/python3.5/site-packages/autograd/core.py in make_vjp(fun, x)
#       8 def make_vjp(fun, x):
#       9     start_node = VJPNode.new_root(x)
# ---> 10     end_value, end_node =  trace(start_node, fun, x)
#      11     if end_node is None:
#      12         def vjp(g): return vspace(x).zeros()
#
# /Users/Nurgetson/anaconda/lib/python3.5/site-packages/autograd/tracer.py in trace(start_node, fun, x)
#       8     with trace_stack.new_trace() as t:
#       9         start_box = new_box(x, t, start_node)
# ---> 10         end_box = fun(start_box)
#      11         if isbox(end_box) and end_box._trace == start_box._trace:
#      12             return end_box._value, end_box._node
#
# /Users/Nurgetson/anaconda/lib/python3.5/site-packages/autograd/wrap_util.py in unary_f(x)
#      13                 else:
#      14                     subargs = subvals(args, zip(argnum, x))
# ---> 15                 return fun(*subargs, **kwargs)
#      16             if isinstance(argnum, int):
#      17                 x = args[argnum]
#
# /Users/Nurgetson/Dropbox/github_repos/mlrefined/mlrefined_libraries/convnets_library/cost_functions.py in twoclass_softmax(self, w)
#      32     # two-class softmax / logistic regression cost
#      33     def twoclass_softmax(self,w):
# ---> 34         cost = np.sum(np.log(1 + np.exp((-self.y)*(self.predict(self.x,w)))))
#      35         return cost
#      36
#
# /Users/Nurgetson/Dropbox/github_repos/mlrefined/mlrefined_libraries/convnets_library/network_learner.py in predict_training(self, x, w)
#      90     def predict_training(self,x,w):
#      91         # feature trasnsformations
# ---> 92         f = self.architectures.training_architecture(x,w[0],w[1])
#      93
#      94         # compute linear model
#
# /Users/Nurgetson/Dropbox/github_repos/mlrefined/mlrefined_libraries/convnets_library/architectures.py in compute_general_network_features(self, x, inner_weights, kernels)
#     137             # compute the mean and standard deviation of the activation output distributions
#     138             a_means = np.mean(a,axis = 0)
# --> 139             a_stds = np.std(a,axis = 0)
#     140
#     141             # normalize the activation outputs
#
# /Users/Nurgetson/anaconda/lib/python3.5/site-packages/autograd/tracer.py in f_wrapped(*args, **kwargs)
#      42             parents = tuple(box._node for _     , box in boxed_args)
#      43             argnums = tuple(argnum    for argnum, _   in boxed_args)
# ---> 44             ans = f_wrapped(*argvals, **kwargs)
#      45             node = node_constructor(ans, f_wrapped, argvals, kwargs, argnums, parents)
#      46             return new_box(ans, trace, node)
#
# /Users/Nurgetson/anaconda/lib/python3.5/site-packages/autograd/tracer.py in f_wrapped(*args, **kwargs)
#      46             return new_box(ans, trace, node)
#      47         else:
# ---> 48             return f_raw(*args, **kwargs)
#      49     f_wrapped.fun = f_raw
#      50     f_wrapped._is_autograd_primitive = True
#
# /Users/Nurgetson/anaconda/lib/python3.5/site-packages/numpy/core/fromnumeric.py in std(a, axis, dtype, out, ddof, keepdims)
#    3005
#    3006     return _methods._std(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# -> 3007                          **kwargs)
#    3008
#    3009
#
# /Users/Nurgetson/anaconda/lib/python3.5/site-packages/numpy/core/_methods.py in _std(a, axis, dtype, out, ddof, keepdims)
#     136
#     137     if isinstance(ret, mu.ndarray):
# --> 138         ret = um.sqrt(ret, out=ret)
#     139     elif hasattr(ret, 'dtype'):
#     140         ret = ret.dtype.type(um.sqrt(ret))
#
# AttributeError: 'float' object has no attribute 'sqrt'

# %%
np.shape(demo.w_init[1])
# Out:
# (10, 3, 3)

# %%
# compute cost plots on training and testing data
demo.compute_cost_plots()

# compute lowest testing misclassifications
ind_min = np.argmin(demo.test_count_history)
test_min = demo.test_count_history[ind_min]
train_min = demo.train_count_history[ind_min]
print ('test misclassifications = ' + str(int(test_min)))
print ('train misclassifications = ' + str(int(train_min)))
# Out:
# test misclassifications = 19
# train misclassifications = 4

# %%
# produce cost functio plots for training and testing data
demo.plot_histories(start = 0)
# Out:
# <img src="data:image/png;base64,..." width="799.9999826604674">
